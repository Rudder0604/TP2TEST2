# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler

df = pd.read_csv("C:/Users/skabe/OneDrive/Documents/Rudder_Works/SCHOOL/MUT[I.T]/Technical Programming II/2024/TEST 2/bky6-3za5.csv")

# Understanding the dataset

# Display the first few rows of the dataset
print("First few rows of the dataset:")
print(df.head())

# Display the size of the dataset
print("\nSize of the dataset:")
print(df.shape)

# Display the data types of each column
print("\nData types of each column:")
print(df.dtypes)

# Display the columns of the dataset
print("\nColumns in the dataset:")
print(df.columns)

# Display summary statistics
print("\nSummary statistics:")
print(df.describe())

# Data slicing and indexing
print("\nData slicing and indexing example:")
print(df.iloc[:5, :3])  # Display the first 5 rows and first 3 columns

# Identify missing data
print("\nMissing data in each column:")
print(df.isnull().sum())


# Numerical data - suitable for regression, clustering, etc.
print("\nstructure_count example:")
print(df['structure_count'].head())

# Categorical data - suitable for classification, one-hot encoding, etc.
print("\nage_of_is example:")
print(df['age_of_is'].head())

# Boolean data - suitable for binary classification
#print("\nBoolean data example:")
#print(df['boolean_column'].head())

# DateTime data - suitable for time series analysis
print("\navg_hhsize example:")
print(df['avg_hhsize'].head())
# Out:
# First few rows of the dataset:
#     is_cluster  pocket_name                pocket_alias   ward_id  \
# 0       4 in 1       4 in 1  Wallacedene 14 / J Section  19100006
# 1  Acacia Road  Acacia Road      Acacia Park - Parktown  19100066
# 2    Amy Biehl    Amy Biehl                 School Site  19100034
# 3  Appel Boord  Appel Boord                         NaN  19100022
# 4       Area K       Area K                 Never Never  19100088
#
#            ward_councillor  avg_hhsize  area_ha  density_dwellings  \
# 0      Simpiwe Nonkeyizana        3.72    2.952          50.813008
# 1          Melanie Arendse        4.51    0.070         114.285714
# 2         Fikiswa Nkunzana        2.89    1.711         301.578025
# 3          Johanna Martlow        4.14    0.088         159.090909
# 4  Patrick (Pat) Pietersen        4.17    2.661         249.154453
#
#    structure_count      age_of_is  ... toilets_full_flush  toilets_chemical  \
# ...
